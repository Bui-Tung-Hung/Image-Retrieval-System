# %%
import pandas
df = pandas.read_csv('D:/Projects/doan/data/flickr8k_vi/metadata.csv')
print(df.head())
# Out:
#                                             filepath  \
# 0  data/flickr8k_vi/images/1000268201_693b08cb0e.jpg
# 1  data/flickr8k_vi/images/1000268201_693b08cb0e.jpg
# 2  data/flickr8k_vi/images/1000268201_693b08cb0e.jpg
# 3  data/flickr8k_vi/images/1000268201_693b08cb0e.jpg
# 4  data/flickr8k_vi/images/1000268201_693b08cb0e.jpg
#
#                                                title
# 0  Một đứa trẻ mặc một chiếc váy màu hồng đang le...
# 1             Một cô gái đi vào một tòa nhà bằng gỗ.
# 2            Một cô bé leo lên một nhà chơi bằng gỗ.
# 3  Một cô bé leo lên cầu thang đến nhà chơi của m...
# 4  Một cô bé mặc một chiếc váy màu hồng đi vào ca...

# %%
df['title'] = df['title'].apply(lambda x: '"' + x + '"')

# %%
df.to_csv('metadata.csv', index=False, encoding='utf-8')

# %%
import pandas as pd

df = pd.read_csv("D:/Projects/doan/data/flickr8k_vi/metadata.csv")

print("Các cột trong CSV:", df.columns.tolist())
# Out:
# Các cột trong CSV: ['filepath', 'title']

# %%
#đường dẫn mẫu D:\Projects\doan\data\flickr8k_vi\images\667626_18933d713e.jpg

# %%
df.head()
# Out:
#                                             filepath  \
# 0  data/flickr8k_vi/images/1000268201_693b08cb0e.jpg
# 1  data/flickr8k_vi/images/1000268201_693b08cb0e.jpg
# 2  data/flickr8k_vi/images/1000268201_693b08cb0e.jpg
# 3  data/flickr8k_vi/images/1000268201_693b08cb0e.jpg
# 4  data/flickr8k_vi/images/1000268201_693b08cb0e.jpg
#
#                                                title
# 0  Một đứa trẻ mặc một chiếc váy màu hồng đang le...
# 1             Một cô gái đi vào một tòa nhà bằng gỗ.
# 2            Một cô bé leo lên một nhà chơi bằng gỗ.
# 3  Một cô bé leo lên cầu thang đến nhà chơi của m...
# 4  Một cô bé mặc một chiếc váy màu hồng đi vào ca...

# %%
#đường dẫn trong file csv: data/flickr8k_vi/images/1000268201_693b08cb0e.jpg
#thêm vào D:/Projects/doan/ vào trước các đường dẫn trong cột filepath
df['filepath'] = df['filepath'].apply(lambda x: 'D:/Projects/doan/' + x)
df.head()
df.to_csv('metadata.csv', index=False, encoding='utf-8')
